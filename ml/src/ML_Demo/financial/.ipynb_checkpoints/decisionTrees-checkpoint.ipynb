# %%
import pandas as pd  # this is the standard alias
import numpy as np

# 引入数据
data = pd.read_csv(r"D:\py_projects\ML\ML_Demo\financial\creditGrade_train_data.csv", encoding='utf-8')
print(data.loc[0:2082,:])

#print(data.describe().astype(np.int64).T)
# Out:
#            年份    征信等级 征信量化等级 公司信用等级  公司信用量化等级 货币资金\r\n（万元）  交易性金融资产\r\n（万元）  \
# 0      2013.0  BBBzc-     12     B+       3.0      199.00               0.0
# 1      2014.0     NaN    NaN    NaN       NaN      134.00               0.0
# 2      2015.0     NaN    NaN    NaN       NaN      995.00               0.0
# 3      2013.0   BBBzc     11     B+       3.0      546.23               0.0
# 4      2014.0     NaN    NaN    NaN       NaN       51.48               0.0
# 5      2015.0     NaN    NaN    NaN       NaN      122.75               0.0
# 6      2013.0  BBBzc+     10     B+       3.0      420.27               0.0
# 7      2014.0     NaN    NaN    NaN       NaN      741.78               0.0
# 8      2015.0     NaN    NaN    NaN       NaN      469.07               0.0
# 9      2013.0    Azc-      9      A       2.0       27.85               0.0
# 10     2014.0     NaN    NaN    NaN       NaN       20.27               0.0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier as DTC, export_graphviz
# loading data
X = data.iloc[:, 0:6] 
# label
y = data.iloc[:, 6]
dtc = DTC(criterion='entropy')  # 基于信息熵
dtc.fit(X, y)
print('准确率：', dtc.score(X, y))
with open(r"D:\py_projects\ML\ML_Demo\financial\tree.dot", 'w') as f:
    f = export_graphviz(dtc, feature_names=X.columns, out_file=f)
# Out:
# 准确率： 1.0

# %%
import random
for _ in range(10):
    i = random.randint(0, len(data))
    pred = dtc.predict(X)[i]
    sign = '✗' if y[i] != pred else '✓'
    print(y[i], pred, sign)
# Out:
# 4 4 ✓
# 3 3 ✓
# 3 3 ✓
# 3 3 ✓
# 3 3 ✓
# 3 3 ✓
# 4 4 ✓
# 3 3 ✓
# 3 3 ✓
# 3 3 ✓
